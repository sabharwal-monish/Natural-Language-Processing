# %%
import tensorflow_hub as hub
import tensorflow_text as text

# %%
preprocess_url = "https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3"
encoder_url = "https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/4"

# %%
preprocess_model = hub.KerasLayer(preprocess_url)

# %%
test_text = ['nice movie indeed','I love python programming']
text_preprocessed = preprocess_model(test_text)
text_preprocessed.keys()
# Out:
# dict_keys(['input_type_ids', 'input_mask', 'input_word_ids'])

# %%
bert_mdoel = hub.KerasLayer(encoder_url)

# %%
bert_result = bert_mdoel(text_preprocessed)

# %%
bert_result.keys()
# Out:
# dict_keys(['pooled_output', 'sequence_output', 'encoder_outputs', 'default'])
