# %%
import pandas as pd
from google.colab import files


uploaded = files.upload()

df = pd.read_csv("ecommerceDataset.csv", names=['category', 'description'], header=None)


df
# Out:
#      <input type="file" id="files-25d6f85e-d34d-46cd-b10d-2710a76429bb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-25d6f85e-d34d-46cd-b10d-2710a76429bb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.category.value_counts()
# Out:
# category
# Household                 19313
# Books                     11820
# Electronics               10621
# Clothing & Accessories     8671
# Name: count, dtype: int64

# %%
df.category.replace("Clothing & Accessories", "Clothing_Accessories", inplace=True)

# %%
df['category'] = '_label_' + df['category'].astype(str)
df
# Out:
#                  category                                        description
# 0        _label_Household  Paper Plane Design Framed Wall Hanging Motivat...
# 1        _label_Household  SAF 'Floral' Framed Painting (Wood, 30 inch x ...
# 2        _label_Household  SAF 'UV Textured Modern Art Print Framed' Pain...
# 3        _label_Household  SAF Flower Print Framed Painting (Synthetic, 1...
# 4        _label_Household  Incredible Gifts India Wooden Happy Birthday U...
# ...                   ...                                                ...
# 50420  _label_Electronics  Strontium MicroSD Class 10 8GB Memory Card (Bl...
# 50421  _label_Electronics  CrossBeats Wave Waterproof Bluetooth Wireless ...
# 50422  _label_Electronics  Karbonn Titanium Wind W4 (White) Karbonn Titan...
# 50423  _label_Electronics  Samsung Guru FM Plus (SM-B110E/D, Black) Colou...
# 50424  _label_Electronics                   Micromax Canvas Win W121 (White)
#
# [50425 rows x 2 columns]

# %%
df['category_description'] = df['category'] + " " + df['description']
df
# Out:
#                  category                                        description  \
# 0        _label_Household  Paper Plane Design Framed Wall Hanging Motivat...
# 1        _label_Household  SAF 'Floral' Framed Painting (Wood, 30 inch x ...
# 2        _label_Household  SAF 'UV Textured Modern Art Print Framed' Pain...
# 3        _label_Household  SAF Flower Print Framed Painting (Synthetic, 1...
# 4        _label_Household  Incredible Gifts India Wooden Happy Birthday U...
# ...                   ...                                                ...
# 50420  _label_Electronics  Strontium MicroSD Class 10 8GB Memory Card (Bl...
# 50421  _label_Electronics  CrossBeats Wave Waterproof Bluetooth Wireless ...
# 50422  _label_Electronics  Karbonn Titanium Wind W4 (White) Karbonn Titan...
# 50423  _label_Electronics  Samsung Guru FM Plus (SM-B110E/D, Black) Colou...
# 50424  _label_Electronics                   Micromax Canvas Win W121 (White)
#
# ...

# %%
import re
text = "  VIKI's | Bookcase/Bookshelf (3-Shelf/Shelve, White) | ? . hi"
text = re.sub(r'[^\w\s\']',' ', text)
text = re.sub(' +', " ", text)
text.strip().lower()
# Out:
# "viki's bookcase bookshelf 3 shelf shelve white hi"

# %%
def preprocessing(text):
  text = re.sub(r'[^\w\s\']',' ', text)
  text = re.sub(' +', " ", text)
  return text.strip().lower()

# %%
df['category_description'] = df['category_description'].apply(lambda x: preprocessing(x) if isinstance(x, str) else '')
df
# Out:
#                  category                                        description  \
# 0        _label_Household  Paper Plane Design Framed Wall Hanging Motivat...
# 1        _label_Household  SAF 'Floral' Framed Painting (Wood, 30 inch x ...
# 2        _label_Household  SAF 'UV Textured Modern Art Print Framed' Pain...
# 3        _label_Household  SAF Flower Print Framed Painting (Synthetic, 1...
# 4        _label_Household  Incredible Gifts India Wooden Happy Birthday U...
# ...                   ...                                                ...
# 50420  _label_Electronics  Strontium MicroSD Class 10 8GB Memory Card (Bl...
# 50421  _label_Electronics  CrossBeats Wave Waterproof Bluetooth Wireless ...
# 50422  _label_Electronics  Karbonn Titanium Wind W4 (White) Karbonn Titan...
# 50423  _label_Electronics  Samsung Guru FM Plus (SM-B110E/D, Black) Colou...
# 50424  _label_Electronics                   Micromax Canvas Win W121 (White)
#
# ...

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(df, test_size=0.2)

# %%
train.to_csv("ecommerce.train", columns=["category_description"], index=False, header=False)
test.to_csv("ecommerce.test", columns=["category_description"], index=False, header=False)

# %%
# !pip install fasttext
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 1.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached pybind11-2.13.6-py3-none-any.whl.metadata (9.5 kB)
# ...
# Using cached pybind11-2.13.6-py3-none-any.whl (243 kB)
# ...
#   Created wheel for fasttext: filename=fasttext-0.9.3-cp311-cp311-linux_x86_64.whl size=4313504 sha256=2f65d091c02784c83a72e4974c699cafd5e8e36c5a728be95b7be18e615de27f
#   Stored in directory: /root/.cache/pip/wheels/65/4f/35/5057db0249224e9ab55a513fa6b79451473ceb7713017823c3
# Successfully built fasttext
# ...

# %%
import fasttext

model = fasttext.train_supervised(input="ecommerce.train")
model.test("ecommerce.test")
# Out:
# (0, nan, nan)
